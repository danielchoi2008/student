# %%
from emoji import emojize
print(emojize(":thumbs_up: Python is awesome! :grinning_face:"))
# Out:
# 👍 Python is awesome! 😀

# %% [markdown]
# %%html
#
# <h2>HTML Cell Output from Jupyter</h2>
#
# <!-- Body contains the contents of the Document -->
# <body>
#     <table class="table">
#         <thead>
#             <tr>
#                 <th>Make</th>
#                 <th>Model</th>
#                 <th>Year</th>
#                 <th>Color</th>
#                 <th>Price</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Mercedes Benz</td>
#                 <td>S Class Sedan</td>
#                 <td>2022</td>
#                 <td>White</td>
#                 <td>$114,500</td>
#             </tr>
#             <tr>
#                 <td>Lexus</td>
#                 <td>LS 500h AWD</td>
#                 <td>2023</td>
#                 <td>Silver</td>
#                 <td>$114,835</td>
#             </tr>
#             <tr>
#                 <td>Tesla</td>
#                 <td>Model S</td>
#                 <td>2023</td>
#                 <td>Light Blue</td>
#                 <td>$78,490</td>
#             </tr>
#             <tr>
#                 <td>Genesis</td>
#                 <td>G90</td>
#                 <td>2023</td>
#                 <td>White</td>
#                 <td>$88,400</td>
#             </tr>
#             <tr>
#                 <td>BMW</td>
#                 <td>i5</td>
#                 <td>2024</td>
#                 <td>Gray</td>
#                 <td>$66,800</td>
#             </tr>
#             <tr>
#                 <td>Porsche</td>
#                 <td>Taycan</td>
#                 <td>2023</td>
#                 <td>Silver</td>
#                 <td>$86,700</td>
#             </tr>
#             <tr>
#                 <td>Toyota</td>
#                 <td>GR Supra</td>
#                 <td>2024</td>
#                 <td>White</td>
#                 <td>$54,500</td>
#             </tr>
#             <tr>
#                 <td>Audi</td>
#                 <td>A4 40 Premium Plus</td>
#                 <td>2023</td>
#                 <td>White</td>
#                 <td>$47,270</td>
#             </tr>
#             <tr>
#                 <td>Honda</td>
#                 <td>Accord Touring Hybrid</td>
#                 <td>2024</td>
#                 <td>Blue</td>
#                 <td>$38,190</td>
#             </tr>
#             <tr>
#                 <td>Volvo</td>
#                 <td>S90</td>
#                 <td>2024</td>
#                 <td>Silver</td>
#                 <td>$57,700</td>
#             </tr>
#             <tr>
#                 <td>Hyundai</td>
#                 <td>Elantra HEV</td>
#                 <td>2023</td>
#                 <td>Gray</td>
#                 <td>$31,245</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
